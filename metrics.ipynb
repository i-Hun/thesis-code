# %%
from pymongo import MongoClient
import pandas as pd
from bson.objectid import ObjectId
import numpy as np
from collections import defaultdict
from tqdm import tnrange, tqdm_notebook
# from topics_by_id import get_topic_by_id

# %%
# %load topics_by_id.py
def get_topic_by_id(id):
    TOPICS_NUMBERING = {
        0: "Accidents with children",
        1: "Local authorities: appointments, resignations & statements",
        2: "*Urban development (misc)",
        3: "IT & military high tech",
        4: "Fires",
        5: "Urban demography & housing payments",
        6: "Police actions drug, alcohol & counterfeit money crimes",
        7: "Omsk region industrial developemnt",
        8: "Ads of banking services",
        9: "Holidays and VIP-weddingss",
        10: "Trials on economic crime",
        11: "Public transport and traffic",
        12: "Weather",
        13: "Yury Gamburg resignation",
        14: "*NATO warships in Black sea, Russian rocket launch & contests",
        15: "Regional parliament activities",
        16: "Urban landscaping & greening",
        17: "Schools, orphanages & child charity",
        18: "Car sales",
        19: "Car accidents",
        20: "Education",
        21: "Real estate: contruction",
        22: "Art and literature",
        23: "Street & bridge reconstruction & maintenance",
        24: "Housing & the case of disabled Akhmetov",
        25: "Stray dogs & doghunters",
        26: "Urban events & openings",
        27: "Crimea accession",
        28: "Concerts",
        29: "Sport, hockey",
        30: "Hockey",
        31: "Control & regulation of enterprises",
        32: "Regional taxes & fuel prices",
        33: "Missing persons announcements",
        34: "Theaters & festivals",
        35: "*Omsk media, plants & animals",
        36: "Local authorities: appointments, resignations & statements",
        37: "Macroeconomic events: currency rates & oil prices",
        38: "Housing: heating",
        39: "Russia, Ukraine & US international relations",
        40: "Beauty contests & their winners",
        41: "Arbitration court and the Mostovik case",
        42: "*Military holidays",
        43: "Criminal news",
        44: "Movies and Movie stars",
        45: "Olympic Games 2014 & Omsk athletes",
        46: "Uninterpretable",
        47: "Ivan Klimov’s murder",
        48: "Abridgments of traffic law",
        49: "Regional elections and misc."
    }
    return TOPICS_NUMBERING[id]

# %%
db = MongoClient().thesis

# %%
db.final_db.find_one()
# Out:
# {'_id': ObjectId('5489d17037a808115d1e6c24'),
#  'title': 'В Омске пассажир автобуса украл у кондуктора золото',
#  'url': 'http://www.bk55.ru/news/article/37963/',
#  'topics': {'0': 0.0002985074626865674,
#   '1': 0.0002985074626865674,
#   '2': 0.0002985074626865674,
#   '3': 0.0002985074626865674,
#   '4': 0.0002985074626865674,
#   '5': 0.0002985074626865674,
#   '6': 0.0002985074626865674,
#   '7': 0.0002985074626865674,
#   '8': 0.0002985074626865674,
#   '9': 0.0002985074626865674,
#   '10': 0.0002985074626865674,
#   '11': 0.2120111568533553,
#   '12': 0.0002985074626865674,
#   '13': 0.0002985074626865674,
#   '14': 0.0002985074626865674,
#   '15': 0.0002985074626865674,
#   '16': 0.0002985074626865674,
#   '17': 0.0002985074626865674,
#   '18': 0.0002985074626865674,
#   '19': 0.09570981130061927,
#   '20': 0.0002985074626865674,
#   '21': 0.0002985074626865674,
#   '22': 0.0002985074626865674,
#   '23': 0.0002985074626865674,
#   '24': 0.0002985074626865674,
#   '25': 0.0002985074626865674,
#   '26': 0.0002985074626865674,
#   '27': 0.0002985074626865674,
#   '28': 0.0002985074626865674,
#   '29': 0.0002985074626865674,
#   '30': 0.0002985074626865674,
#   '31': 0.0002985074626865674,
#   '32': 0.10735985254053867,
#   '33': 0.0002985074626865674,
#   '34': 0.0002985074626865674,
#   '35': 0.0002985074626865674,
#   '36': 0.0002985074626865674,
#   '37': 0.0002985074626865674,
#   '38': 0.0002985074626865674,
#   '39': 0.0002985074626865674,
#   '40': 0.0002985074626865674,
#   '41': 0.0002985074626865674,
#   '42': 0.0002985074626865674,
#   '43': 0.5711878360219053,
#   '44': 0.0002985074626865674,
#   '45': 0.0002985074626865674,
#   '46': 0.0002985074626865674,
#   '47': 0.0002985074626865674,
#   '48': 0.0002985074626865674,
#   '49': 0.0002985074626865674},
#  'comments': [['в настоящий время он давать показание. анна давыдова источник: http://bk55.ru/news/article/37963/ как до-о-о-олго он они давать…\n',
#    0,
#    0]],
#  'content': ['омск',
#   'пассажир',
#   'автобус',
#   'украсть',
#   'кондуктор',
#   'золото',
#   'женщина',
#   'лишиться',
#   'золотой',
#   'изделие',
#   'сумма',
#   'около',
#   '7',
#   'тысяча',
#   'рубль',
#   'прямо',
#   'салон',
#   'автобус',
#   'вчера',
#   '31',
#   'август',
#   'полиция',
#   'поступить',
#   'сообщение',
#   'грабёж',
#   'около',
#   '17',
#   'часы',
#   'остановка',
#   'улица',
#   'б',
#   'хмельницкий',
#   'прямо',
#   'салон',
#   'автобус',
#   'ограбить',
#   'кондуктор',
#   'омск',
#   'транспортный',
#   'предприятие',
#   'слово',
#   'пострадать',
#   'неизвестный',
#   'похитить',
#   'нея',
#   'золотой',
#   'изделие',
#   'общий',
#   'стоимость',
#   '7',
#   'тысяча',
#   'рубль',
#   'подозревать',
#   'вскоре',
#   'задержать',
#   'имя',
#   'оказаться',
#   'ранее',
#   'судить',
#   'безработный',
#   '30-летний',
#   'омич',
#   'настоящее',
#   'время',
#   'давать',
#   'показание'],
#  'source': 'bk55_preprocessed',
#  'date': datetime.datetime(2014, 9, 1, 0, 0),
#  'commentsCount': 1,
#  'content_raw': 'Женщина лишилась золотых изделий на сумму около 7 тысяч рублей прямо в салоне автобуса. Вчера, 31 августа, в полицию поступило сообщение о грабеже. Около 17 часов на остановке по улице Б. Хмельницкого прямо в салоне автобуса ограбили кондуктора одного из омских транспортных предприятий. По словам пострадавшей, неизвестный похитил у нее золотые изделия общей стоимостью почти 7 тысяч рублей. Подозреваемый вскоре был задержан, им оказался ранее судимый безработный 30-летний омич. В настоящее время он дает показания. '}

# %%
crimea_dict = {}

for num, doc in enumerate(db.final_db.find()):
    print(num, end="\r")
    in_title = "крым" in doc["title"].lower()
    in_content = "крым" in doc["content_raw"].lower()
    if in_title or in_content:
        crimea_dict[doc["url"]] = {
            "in_title": in_title,
            "in_content": in_content,
            "_id": doc["_id"]
        }
# Out:
# 33874

# %%
crimea = pd.DataFrame.from_dict(crimea_dict, orient="index")

# %%
crimea.head()
# Out:
#                                                     in_title  in_content  \
# http://gorod55.ru/news/article/014ef3ad-ca08-4a...     False        True
# http://gorod55.ru/news/article/028583fa-5cc1-43...      True        True
# http://gorod55.ru/news/article/02c1e5af-442d-44...      True        True
# http://gorod55.ru/news/article/0507cbb6-6fd7-40...     False        True
# http://gorod55.ru/news/article/07a7733f-3d5e-4b...     False        True
#
#                                                                          _id
# http://gorod55.ru/news/article/014ef3ad-ca08-4a...  5489d9e337a808115d1eb2a5
# http://gorod55.ru/news/article/028583fa-5cc1-43...  5489d8bb37a808115d1ea934
# http://gorod55.ru/news/article/02c1e5af-442d-44...  5489d9bf37a808115d1eb16e
# http://gorod55.ru/news/article/0507cbb6-6fd7-40...  5489d97637a808115d1eaf41
# http://gorod55.ru/news/article/07a7733f-3d5e-4b...  5489d9c137a808115d1eb185

# %%
topic_results = {}

for _id in crimea["_id"].dropna().tolist():
    doc = db.final_db.find_one({"_id": ObjectId(_id)})
    
    sent_scores = [comment[-1] for comment in doc["comments"]]
    comments_num = len(doc["comments"])
    
    if comments_num:
        avg_comment_sent = sum(sent_scores)/comments_num
        avg_comment_std = np.std(sent_scores)

        for topic, prob in doc["topics"].items():
            topic = get_topic_by_id(int(topic))
            topic_results.setdefault(topic, defaultdict(int))
            topic_results[topic]["comments_num"] += prob * comments_num           
            topic_results[topic]["avg_comment_sent"] += prob * avg_comment_sent
            topic_results[topic]["avg_comment_std"] += prob * avg_comment_std

# %%
topics_sum = {}

for _id in tqdm_notebook(crimea["_id"].dropna().tolist()):
    doc = db.final_db.find_one({"_id": ObjectId(_id)})
    
    for topic, prob in doc["topics"].items():
        topic = get_topic_by_id(int(topic))
        
        topics_sum.setdefault(topic, 0)
        topics_sum[topic] += prob
# Out:
# HBox(children=(IntProgress(value=0, max=825), HTML(value='')))

# %%
topic_results_df = pd.DataFrame.from_dict(topic_results, orient="columns")
topic_results_df
# Out:
#                   *Military holidays  \
# avg_comment_sent            2.863734
# avg_comment_std             5.478044
# comments_num              131.501857
#
#                   *NATO warships in Black sea, Russian rocket launch & contests  \
# avg_comment_sent                                           1.183613
# avg_comment_std                                            3.196276
# comments_num                                             158.845998
#
#                   *Omsk media, plants & animals  *Urban development (misc)  \
# avg_comment_sent                       1.008970                   7.034216
# avg_comment_std                        1.961055                  16.015276
# comments_num                          37.652366                 459.607222
#
#                   Abridgments of traffic law  Accidents with children  \
# avg_comment_sent                    0.648740                 0.422359
# avg_comment_std                     1.147078                 0.728695
# comments_num                       26.124015                20.846283
#
#                   Ads of banking services  \
# avg_comment_sent                 0.755008
# avg_comment_std                  1.770340
# comments_num                    45.673728
#
#                   Arbitration court and the Mostovik case  Art and literature  \
# avg_comment_sent                                 1.880956            1.326721
# avg_comment_std                                  2.778885            3.125302
# comments_num                                    87.740923           77.214581
#
#                   Beauty contests & their winners            ...             \
# avg_comment_sent                         4.371830            ...
# avg_comment_std                          5.825103            ...
# comments_num                           155.734849            ...
#
#                   Stray dogs & doghunters  \
# avg_comment_sent                 4.143805
# avg_comment_std                 12.246031
# comments_num                   412.669912
#
#                   Street & bridge reconstruction & maintenance  \
# avg_comment_sent                                      0.654998
# avg_comment_std                                       1.517704
# comments_num                                         41.167687
#
#                   Theaters & festivals  Trials on economic crime  \
# avg_comment_sent              1.245163                  0.801112
# avg_comment_std               2.649789                  2.100651
# comments_num                 72.938583                 66.191943
#
#                   Uninterpretable  Urban demography & housing payments  \
# avg_comment_sent         2.956542                             2.500416
# avg_comment_std          6.353951                             3.644941
# comments_num           183.195142                           117.765113
#
#                   Urban events & openings  Urban landscaping & greening  \
# avg_comment_sent                 1.714384                      1.656302
# avg_comment_std                  2.988933                      2.291127
# comments_num                    82.841915                     46.875472
#
#                     Weather  Yury Gamburg resignation
# avg_comment_sent   0.416344                  2.612819
# avg_comment_std    1.603462                  7.102884
# comments_num      29.239336                317.279639
#
# [3 rows x 49 columns]

# %%
topics_sum_df = pd.Series(topics_sum)
topics_sum_df
# Out:
# *Military holidays                                                12.218537
# *NATO warships in Black sea, Russian rocket launch & contests      7.689874
# *Omsk media, plants & animals                                      4.566573
# *Urban development (misc)                                         40.813866
# Abridgments of traffic law                                         2.171464
# Accidents with children                                            2.188863
# Ads of banking services                                            5.440356
# Arbitration court and the Mostovik case                            8.057398
# Art and literature                                                 7.863337
# Beauty contests & their winners                                   16.135863
# Car accidents                                                      1.441840
# Car sales                                                          1.917343
# Concerts                                                           6.824793
# Control & regulation of enterprises                                2.055422
# Crimea accession                                                  80.233119
# Criminal news                                                      2.356591
# Education                                                         10.404392
# Fires                                                              5.165611
# Hockey                                                             1.056553
# Holidays and VIP-weddingss                                        10.503532
# Housing & the case of disabled Akhmetov                            7.082828
# Housing: heating                                                   4.388922
# IT & military high tech                                            8.017312
# Ivan Klimov’s murder                                               3.594705
# Local authorities: appointments, resignations & statements        63.773918
# Macroeconomic events: currency rates & oil prices                 41.319779
# Missing persons announcements                                      2.051958
# Movies and Movie stars                                             5.883447
# Olympic Games 2014 & Omsk athletes                                 6.760143
# Omsk region industrial developemnt                                23.225915
# Police actions drug, alcohol & counterfeit money crimes            4.619711
# Public transport and traffic                                       5.583345
# Real estate: contruction                                           8.844770
# Regional elections and misc.                                       2.427255
# Regional parliament activities                                    31.419258
# Regional taxes & fuel prices                                      28.170829
# Russia, Ukraine & US international relations                     226.607481
# Schools, orphanages & child charity                                7.658128
# Sport, hockey                                                      3.716826
# Stray dogs & doghunters                                           28.867946
# Street & bridge reconstruction & maintenance                       3.598810
# Theaters & festivals                                               8.466281
# Trials on economic crime                                           6.264132
# Uninterpretable                                                   16.087088
# Urban demography & housing payments                               11.839524
# Urban events & openings                                            7.503077
# Urban landscaping & greening                                       6.007304
# Weather                                                            6.969980
# Yury Gamburg resignation                                          15.143998
# dtype: float64

# %%
topic_results_df/topics_sum_df
# Out:
#                   *Military holidays  \
# avg_comment_sent            0.234376
# avg_comment_std             0.448339
# comments_num               10.762488
#
#                   *NATO warships in Black sea, Russian rocket launch & contests  \
# avg_comment_sent                                           0.153918
# avg_comment_std                                            0.415647
# comments_num                                              20.656516
#
#                   *Omsk media, plants & animals  *Urban development (misc)  \
# avg_comment_sent                       0.220947                   0.172349
# avg_comment_std                        0.429437                   0.392398
# comments_num                           8.245213                  11.261056
#
#                   Abridgments of traffic law  Accidents with children  \
# avg_comment_sent                    0.298757                 0.192958
# avg_comment_std                     0.528251                 0.332910
# comments_num                       12.030598                 9.523795
#
#                   Ads of banking services  \
# avg_comment_sent                 0.138779
# avg_comment_std                  0.325409
# comments_num                     8.395356
#
#                   Arbitration court and the Mostovik case  Art and literature  \
# avg_comment_sent                                 0.233445            0.168722
# avg_comment_std                                  0.344886            0.397452
# comments_num                                    10.889486            9.819569
#
#                   Beauty contests & their winners            ...             \
# avg_comment_sent                         0.270939            ...
# avg_comment_std                          0.361003            ...
# comments_num                             9.651473            ...
#
#                   Stray dogs & doghunters  \
# avg_comment_sent                 0.143543
# avg_comment_std                  0.424209
# comments_num                    14.295091
#
#                   Street & bridge reconstruction & maintenance  \
# avg_comment_sent                                      0.182004
# avg_comment_std                                       0.421724
# comments_num                                         11.439248
#
#                   Theaters & festivals  Trials on economic crime  \
# avg_comment_sent              0.147073                  0.127889
# avg_comment_std               0.312981                  0.335346
# comments_num                  8.615186                 10.566817
#
#                   Uninterpretable  Urban demography & housing payments  \
# avg_comment_sent         0.183784                             0.211192
# avg_comment_std          0.394972                             0.307862
# comments_num            11.387713                             9.946778
#
#                   Urban events & openings  Urban landscaping & greening  \
# avg_comment_sent                 0.228491                      0.275715
# avg_comment_std                  0.398361                      0.381390
# comments_num                    11.041059                      7.803080
#
#                    Weather  Yury Gamburg resignation
# avg_comment_sent  0.059734                  0.172532
# avg_comment_std   0.230053                  0.469023
# comments_num      4.195039                 20.950850
#
# [3 rows x 49 columns]
