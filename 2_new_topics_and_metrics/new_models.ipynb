# %%
from pymongo import MongoClient, DESCENDING, ASCENDING
from bson.objectid import ObjectId
import csv
from tqdm import tnrange, tqdm_notebook
import pandas as pd

from gensim.corpora import Dictionary
from gensim import models
import numpy as np


db = MongoClient().thesis.final_db
db_raw = MongoClient().thesis.merged

# %%
db.count(), db_raw.count()
# Out:
# (33875, 33877)

# %%
db.find_one()["comments"][0][-1]
# Out:
# 0

# %%
texts = [doc["content"] for doc in db.find()]

# %%
dct = Dictionary(texts)

# %%
len(dct)
# Out:
# 118718

# %%
def find_infrequient(documents):
    """ На входе принимаем токенизированный список документов
    вида [[токен1, токен2], [токен1, токен3]]
    Находим слова, которые встречаются меньше определённого количества раз
    98262 токенов, которые встречаются 2 или 1 раз
    49279 -- 1 раз
    54552 токенов, которые встречаются только в одном документе
    всего 118806
    """

    from collections import Counter

    c = Counter(token for document in documents for token in document)

    infrequient = []

    # Single line: [[token for token in document if c[token] > 1] for document in documents]
    for document in documents:
        for token in document:
            if c[token] <= 1:
                #print "Токен [{0}] встречается {1} раз".decode("utf8").format(token, c[token])
                infrequient.append(token)

    print("Общее количество токенов {0}. Найдёно {1} редких токенов".format(len(c), len(infrequient)))
    return infrequient

# %%
solo_tokens = find_infrequient(texts)
# Out:
# Общее количество токенов 118718. Найдёно 49277 редких токенов

# %%
solo_ids = [_id for _id, token in dct.iteritems() if token in solo_tokens]

# %%
dct.filter_tokens(solo_ids)

# %%
dct.compactify()

# %%
len(dct)
# Out:
# 69441

# %%
corpus = [dct.doc2bow(text) for text in texts]

# %%
models_list = []

for m_num in range(2):
    lda = models.LdaMulticore(corpus=corpus,
                              id2word=dct,
                              num_topics=50,
                              workers=3)
    models_list.append(lda)

# %%
models_list[0].print_topics()
# Out:
# [(45,
#   '0.011*"омск" + 0.009*"конкурс" + 0.008*"россия" + 0.004*"день" + 0.003*"получить" + 0.003*"человек" + 0.003*"дорога" + 0.003*"новый" + 0.003*"область" + 0.003*"работа"'),
#  (13,
#   '0.014*"омск" + 0.012*"омичка" + 0.008*"градус" + 0.007*"область" + 0.006*"температура" + 0.006*"россия" + 0.005*"команда" + 0.004*"ребёнок" + 0.004*"матч" + 0.004*"днём"'),
#  (43,
#   '0.015*"россия" + 0.008*"украина" + 0.006*"омск" + 0.004*"район" + 0.004*"выбор" + 0.004*"область" + 0.003*"глава" + 0.003*"страна" + 0.003*"рубль" + 0.003*"место"'),
#  (18,
#   '0.015*"омск" + 0.012*"строительство" + 0.008*"работа" + 0.006*"объект" + 0.005*"район" + 0.005*"улица" + 0.005*"область" + 0.004*"мостовик" + 0.004*"компания" + 0.004*"дом"'),
#  (33,
#   '0.015*"омск" + 0.006*"россия" + 0.005*"автомобиль" + 0.005*"область" + 0.004*"рубль" + 0.004*"человек" + 0.004*"время" + 0.004*"омич" + 0.004*"город" + 0.003*"улица"'),
#  (44,
#   '0.025*"омск" + 0.014*"область" + 0.010*"россия" + 0.008*"губернатор" + 0.008*"регион" + 0.007*"назаров" + 0.006*"глава" + 0.005*"виктор" + 0.005*"вопрос" + 0.004*"правительство"'),
#   '0.027*"улица" + 0.017*"омск" + 0.008*"город" + 0.007*"транспорт" + 0.006*"день" + 0.006*"движение" + 0.006*"маршрут" + 0.005*"время" + 0.005*"эстафета" + 0.004*"пробка"')]

# %%
new_dataset = {}

for num, doc in enumerate(db.find()):
    print(num, end="\r")
    
    bow = dct.doc2bow(doc["content"])
    probs1 = models_list[0].get_document_topics(bow, minimum_probability=0)
    probs2 = models_list[1].get_document_topics(bow, minimum_probability=0)
    
    try:
        raw_doc = db_raw.find_one({"url": doc["url"]})
    except Exception as err:
        if doc["source"] == "bk55_preprocessed":
            raw_doc = MongoClient().thesis.bk55_preprocessed.find_one({"url": doc["url"]})
        if doc["source"] == "gorod55":
            raw_doc = MongoClient().thesis.gorod55.find_one({"url": doc["url"]})
        if doc["source"] == "ngs55":
            raw_doc = MongoClient().thesis.ngs55.find_one({"url": doc["url"]})
        if doc["source"] == "omskinform":
            raw_doc = MongoClient().thesis.omskinform.find_one({"url": doc["url"]})
        else:
            break
        
    try:
        d = {
            "_id": str(doc["_id"]),
            "topics1": probs1,
            "topics2": probs2,
            "title": doc["title"],
            "source": doc["url"],
            "content": raw_doc["content"],
            "comments": doc["comments"]
        }
        new_dataset[doc["url"]] = d
    except Exception as err:
        print(err)
        print(doc)
# Out:
# 33874

# %%
len(new_dataset)
# Out:
# 33871

# %%
new_dataset["http://www.bk55.ru/news/article/37963/"]
# Out:
# {'_id': '5489d17037a808115d1e6c24',
#  'comments': [['в настоящий время он давать показание. анна давыдова источник: http://bk55.ru/news/article/37963/ как до-о-о-олго он они давать…\n',
#    0,
#    0]],
#  'content': 'Женщина лишилась золотых изделий на сумму около 7 тысяч рублей прямо в салоне автобуса. Вчера, 31 августа, в полицию поступило сообщение о грабеже. Около 17 часов на остановке по улице Б. Хмельницкого прямо в салоне автобуса ограбили кондуктора одного из омских транспортных предприятий. По словам пострадавшей, неизвестный похитил у нее золотые изделия общей стоимостью почти 7 тысяч рублей. Подозреваемый вскоре был задержан, им оказался ранее судимый безработный 30-летний омич. В настоящее время он дает показания. ',
#  'source': 'http://www.bk55.ru/news/article/37963/',
#  'title': 'В Омске пассажир автобуса украл у кондуктора золото',
#  'topics1': [(0, 0.00029850742),
#   (1, 0.00029850742),
#   (2, 0.00029850742),
#   (3, 0.00029850742),
#   (4, 0.00029850742),
#   (5, 0.00029850742),
#   (6, 0.00029850742),
#   (7, 0.00029850742),
#   (8, 0.00029850742),
#   (9, 0.00029850742),
#   (10, 0.00029850742),
#   (11, 0.00029850742),
#   (12, 0.00029850742),
#   (13, 0.00029850742),
#   (14, 0.37536335),
#   (15, 0.00029850742),
#   (16, 0.00029850742),
#   (17, 0.00029850742),
#   (18, 0.00029850742),
#   (19, 0.00029850742),
#   (20, 0.00029850742),
#   (21, 0.00029850742),
#   (22, 0.00029850742),
#   (23, 0.00029850742),
#   (24, 0.00029850742),
#   (25, 0.00029850742),
#   (26, 0.00029850742),
#   (27, 0.00029850742),
#   (28, 0.00029850742),
#   (29, 0.00029850742),
#   (30, 0.00029850742),
#   (31, 0.00029850742),
#   (32, 0.00029850742),
#   (33, 0.00029850742),
#   (34, 0.00029850742),
#   (35, 0.00029850742),
#   (36, 0.00029850742),
#   (37, 0.00029850742),
#   (38, 0.00029850742),
#   (39, 0.00029850742),
#   (40, 0.00029850742),
#   (41, 0.00029850742),
#   (42, 0.00029850742),
#   (43, 0.00029850742),
#   (44, 0.00029850742),
#   (45, 0.00029850742),
#   (46, 0.00029850742),
#   (47, 0.00029850742),
#   (48, 0.6103083),
#   (49, 0.00029850742)],
#  'topics2': [(0, 0.00029850745),
#   (1, 0.00029850745),
#   (2, 0.00029850745),
#   (3, 0.00029850745),
#   (4, 0.00029850745),
#   (5, 0.00029850745),
#   (6, 0.00029850745),
#   (7, 0.00029850745),
#   (8, 0.00029850745),
#   (9, 0.00029850745),
#   (10, 0.00029850745),
#   (11, 0.2555329),
#   (12, 0.00029850745),
#   (13, 0.00029850745),
#   (14, 0.00029850745),
#   (15, 0.00029850745),
#   (16, 0.00029850745),
#   (17, 0.00029850745),
#   (18, 0.00029850745),
#   (19, 0.00029850745),
#   (20, 0.00029850745),
#   (21, 0.00029850745),
#   (22, 0.00029850745),
#   (23, 0.00029850745),
#   (24, 0.00029850745),
#   (25, 0.00029850745),
#   (26, 0.00029850745),
#   (27, 0.00029850745),
#   (28, 0.00029850745),
#   (29, 0.00029850745),
#   (30, 0.00029850745),
#   (31, 0.5939301),
#   (32, 0.00029850745),
#   (33, 0.00029850745),
#   (34, 0.00029850745),
#   (35, 0.13650705),
#   (36, 0.00029850745),
#   (37, 0.00029850745),
#   (38, 0.00029850745),
#   (39, 0.00029850745),
#   (40, 0.00029850745),
#   (41, 0.00029850745),
#   (42, 0.00029850745),
#   (43, 0.00029850745),
#   (44, 0.00029850745),
#   (45, 0.00029850745),
#   (46, 0.00029850745),
#   (47, 0.00029850745),
#   (48, 0.00029850745),
#   (49, 0.00029850745)]}

# %%
from collections import defaultdict

# %%
topic1_results = {}
topic2_results = {}

for url, doc in tqdm_notebook(new_dataset.items()):
    sent_scores = [comment[-1] for comment in doc["comments"]]
    comments_num = len(doc["comments"])
    
    if comments_num:
        avg_comment_sent = sum(sent_scores)/comments_num
        avg_comment_std = np.std(sent_scores)

        for topic, prob in doc["topics1"] :
            topic1_results.setdefault(topic, defaultdict(int))

            topic1_results[topic]["comments_num"] += prob * comments_num           
            topic1_results[topic]["avg_comment_sent"] += prob * avg_comment_sent
            topic1_results[topic]["avg_comment_std"] += prob * avg_comment_std

        for topic, prob in doc["topics2"]:
            topic2_results.setdefault(topic, defaultdict(int))

            topic2_results[topic]["comments_num"] += prob * comments_num           
            topic2_results[topic]["avg_comment_sent"] += prob * avg_comment_sent
            topic2_results[topic]["avg_comment_std"] += prob * avg_comment_std
# Out:
# HBox(children=(IntProgress(value=0, max=33871), HTML(value='')))

# %%
topic1_sum = {}
topic2_sum = {}

for url, doc in tqdm_notebook(new_dataset.items()):
    for topic, prob in doc["topics1"] :
        topic1_sum.setdefault(topic, 0)

        topic1_sum[topic] += prob          

    for topic, prob in doc["topics2"]:
        topic2_sum.setdefault(topic, 0)

        topic2_sum[topic] += prob
# Out:
# HBox(children=(IntProgress(value=0, max=33871), HTML(value='')))

# %%
topcs_sum_df = pd.concat([pd.DataFrame.from_dict(topic1_sum, orient="index").transpose(),
           pd.DataFrame.from_dict(topic2_sum, orient="index").transpose()],
           ignore_index=True
         ).transpose()
topcs_sum_df.head()
# Out:
#             0           1
# 0  182.287492  231.052475
# 1  171.369305  544.965852
# 2  450.864556  247.342021
# 3  394.038267  969.297061
# 4  140.591960  253.321139

# %%
df1 = pd.DataFrame(topic1_results)

# %%
df2 = pd.DataFrame(topic2_results)
df2
# Out:
#                            0            1            2            3   \
# avg_comment_sent    43.754400    91.445968    41.403743   145.095126
# avg_comment_std     70.538766   203.360449    92.803585   284.849288
# comments_num      1523.314242  4347.826095  2195.682198  5281.334706
#
#                            4            5            6            7   \
# avg_comment_sent    32.789199    64.067696    73.500323    55.562704
# avg_comment_std     65.303276   185.529653   143.659477   155.873252
# comments_num      1394.340277  5452.999675  3435.863821  4066.090088
#
#                            8             9      ...                40  \
# avg_comment_sent   147.130359    363.712899     ...        190.610999
# avg_comment_std    282.909634    751.205148     ...        239.582621
# comments_num      4913.860759  17694.486395     ...       4409.566284
#
#                            41           42           43           44  \
# avg_comment_sent    43.738161    43.336822   112.455085   124.976907
# avg_comment_std    162.719333    86.495856   233.477277   185.572545
# comments_num      3335.970975  1827.974401  5871.065389  3236.899152
#
#                            45           46           47           48  \
# avg_comment_sent   121.947127    43.861095   140.081289    44.616291
# avg_comment_std    288.795468    80.334863   279.175536   109.653471
# comments_num      5995.992490  1685.909326  5809.104458  2361.965533
#
#                            49
# avg_comment_sent    27.565969
# avg_comment_std     62.553785
# comments_num      1354.109604
#
# [3 rows x 50 columns]

# %%
models_metrics_writer = pd.ExcelWriter("models_metrics.xlsx")

topcs_sum_df.to_excel(models_metrics_writer, "prob_sum")
df1.transpose().to_excel(models_metrics_writer, "model0_metrics")
df2.transpose().to_excel(models_metrics_writer, "model1_metrics")

models_metrics_writer.save()

# %%
def top_docs_for_topic(data, model_num, t_num, limit=50):
    return list(
        sorted(
            data.items(),
            key=lambda doc: doc[1][f"topics{model_num+1}"][t_num],
            reverse=True
        )[:limit],
    )

# %%
top_docs_for_topic(new_dataset, 1, 0)
# Out:
# [('http://www.bk55.ru/news/article/32811/',
#   {'_id': '5489d37c37a808115d1e7d61',
#    'comments': [['35% заявлять что почему-то рваться, а сколько заявлять, что еще и гнуться?))очень информативный исследование…\n',
#      0,
#      0]],
#    'content': 'Известное исследовательское агентство проанализировало недостатки неправильного использования контрацептивов в России. Агентством был проведен опрос, согласно результатам которого россияне считают презерватив самым распространенным средством контрацепции. Выяснилось, что 91% опрошенных считают, что умеют правильно пользоваться этим изделием, а 76% планируют его как средство для предохранения в течение ближайших трех лет. Однако 35% опрошенных сообщили, что презерватив почему-то рвется. Из них половина сослалась на брак производства и лишь четверть призналась в неправильном его использовании. По данным исследований мировой уровень «неудачного изделия» составляет всего лишь 28%. Такое неудачное использование данного средства контрацепции приводит к неутешительным последствиям - 29% процентов россиянок вынуждены делать аборт, что плохо сказывается на и так совсем не прекрасной демографической ситуации в нашей стране. Для сравнения - в остальном мире этот показатель ниже аж в 2 раза - из-за неправильного использования презервативов к аборту вынуждены прибегнуть 14% опрошенных. Также исследователи пытались выяснить действия респондентов в случае неудачного использования презервативов. 10% сообщили, что не предпринимали бы никаких действий, 34% прибегли бы к таблетке экстренной контрацепции в зависимости от цикла, когда действия осуществляются в первые 72 часа после рискованного полового акта. 23% использовали бы экстренную контрацепцию в любом случае, а 29% предприняли бы действия только после беседы с гинекологом. ',
#    'source': 'http://www.bk55.ru/news/article/32811/',
#    'title': 'Millward Brown заинтересовалась умением россиян предохраняться',
#    'topics1': [(0, 0.880246),
#     (1, 0.00014184398),
#     (2, 0.00014184398),
#     (3, 0.00014184398),
#     (4, 0.00014184398),
#     (5, 0.00014184398),
#     (6, 0.00014184398),
#     (7, 0.00014184398),
#     (8, 0.00014184398),
#     (9, 0.00014184398),
#     (10, 0.00014184398),
#     (11, 0.00014184398),
#     (12, 0.00014184398),
#     (13, 0.00014184398),
#     (14, 0.00014184398),
#     (15, 0.00014184398),
#     (16, 0.00014184398),
#     (17, 0.00014184398),
#     (18, 0.00014184398),
#     (19, 0.00014184398),
#     (20, 0.00014184398),
#     (21, 0.00014184398),
#     (22, 0.00014184398),
#     (23, 0.00014184398),
#     (24, 0.00014184398),
#     (25, 0.00014184398),
#     (26, 0.00014184398),
#     (27, 0.00014184398),
#     (28, 0.00014184398),
#     (29, 0.00014184398),
#     (30, 0.00014184398),
#     (31, 0.112945534),
#     (32, 0.00014184398),
#     (33, 0.00014184398),
#     (34, 0.00014184398),
#     (35, 0.00014184398),
#     (36, 0.00014184398),
#     (37, 0.00014184398),
#     (38, 0.00014184398),
#     (39, 0.00014184398),
#     (40, 0.00014184398),
#     (41, 0.00014184398),
#     (42, 0.00014184398),
#     (43, 0.00014184398),
#     (44, 0.00014184398),
#     (45, 0.00014184398),
#     (46, 0.00014184398),
#     (47, 0.00014184398),
#     (48, 0.00014184398),
#     (49, 0.00014184398)],
#    'topics2': [(0, 0.00014184395),
#     (1, 0.00014184395),
#     (2, 0.00014184395),
#     (3, 0.00014184395),
#     (4, 0.06554311),
#     (5, 0.00014184395),
#     (6, 0.00014184395),
#     (7, 0.00014184395),
#     (8, 0.00014184395),
#     (9, 0.00014184395),
#     (10, 0.00014184395),
#     (11, 0.00014184395),
#     (12, 0.00014184395),
#     (13, 0.00014184395),
#     (14, 0.00014184395),
#     (15, 0.00014184395),
#     (16, 0.00014184395),
#     (17, 0.00014184395),
#     (18, 0.00014184395),
#     (19, 0.00014184395),
#     (20, 0.00014184395),
#     (21, 0.00014184395),
#     (22, 0.00014184395),
#     (23, 0.92764837),
#     (24, 0.00014184395),
#     (25, 0.00014184395),
#     (26, 0.00014184395),
#     (27, 0.00014184395),
#     (28, 0.00014184395),
#     (29, 0.00014184395),
#     (30, 0.00014184395),
#     (31, 0.00014184395),
#     (32, 0.00014184395),
#     (33, 0.00014184395),
#     (34, 0.00014184395),
#     (35, 0.00014184395),
#     (36, 0.00014184395),
#     (37, 0.00014184395),
#     (38, 0.00014184395),
#     (39, 0.00014184395),
#     (40, 0.00014184395),
#     (41, 0.00014184395),
#     (42, 0.00014184395),
#     (43, 0.00014184395),
#     (44, 0.00014184395),
#     (45, 0.00014184395),
#     (46, 0.00014184395),
#     (47, 0.00014184395),
#     (48, 0.00014184395),
#     (49, 0.00014184395)]}),
#  ('http://www.bk55.ru/news/article/34978/',
#   {'_id': '5489d2a037a808115d1e760e',
#    'comments': [],
#    'content': 'Контуженные корреспондент Денис Кулага и оператор Вадим Юдин доставлены в больницу. Инцидент, в котором пострадали журналисты, случился в Луганской области рядом с поселком Изварино. Спецкорр канала РЕН-ТВ Денис Кулага и телеоператор Вадим Юдин попали под обстрел украинских военных во время работы на территории птицефабрики. Об этом сообщается в группе канала РЕН-ТВ в соцсети «Вконтакте». «Рядом с журналистами взорвался снаряд, предположительно выпущенный из гаубицы. Денис Кулага контужен, он ничего не слышит, из ушей идет кровь. Контузию получил и оператор. Ударной волной выбило из рук камеру, аппаратура вышла из строя», – говорится в сообщении. Боевые действия между ополченцами Луганской народной республики и представителями Нацгвардии Украины начались сегодня около 9 утра у российско-украинской границы в районе пропускных пунктов Донецк – Изварино и Краснопартизанск – Гуково. ',
#    'source': 'http://www.bk55.ru/news/article/34978/',
#    'title': 'В Луганской области рядом с репортерами РЕН-ТВ взорвался снаряд',
#    'topics1': [(0, 0.8716741),
#     (1, 0.00020408163),
#     (2, 0.00020408163),
#     (3, 0.00020408163),
#     (4, 0.00020408163),
#     (5, 0.00020408163),
#     (6, 0.00020408163),
#     (7, 0.00020408163),
#     (8, 0.00020408163),
#     (9, 0.00020408163),
#     (10, 0.00020408163),
#     (11, 0.00020408163),
#     (12, 0.00020408163),
#     (13, 0.00020408163),
#     (14, 0.00020408163),
#     (15, 0.00020408163),
#     (16, 0.00020408163),
#     (17, 0.00020408163),
#     (18, 0.00020408163),
#     (19, 0.00020408163),
#     (20, 0.00020408163),
#     (21, 0.00020408163),
#     (22, 0.00020408163),
#     (23, 0.00020408163),
#     (24, 0.00020408163),
#     (25, 0.00020408163),
#     (26, 0.00020408163),
#     (27, 0.00020408163),
#     (28, 0.00020408163),
#     (29, 0.00020408163),
#     (30, 0.00020408163),
#     (31, 0.00020408163),
#     (32, 0.00020408163),
#     (33, 0.00020408163),
#     (34, 0.00020408163),
#     (35, 0.00020408163),
#     (36, 0.00020408163),
#     (37, 0.00020408163),
#     (38, 0.00020408163),
#     (39, 0.00020408163),
#     (40, 0.00020408163),
#     (41, 0.00020408163),
#     (42, 0.00020408163),
#     (43, 0.11852992),
#     (44, 0.00020408163),
#     (45, 0.00020408163),
#     (46, 0.00020408163),
#     (47, 0.00020408163),
#     (48, 0.00020408163),
#     (49, 0.00020408163)],
#    'topics2': [(0, 0.00020408163),
#     (1, 0.00020408163),
#     (2, 0.00020408163),
#     (3, 0.00020408163),
#     (4, 0.00020408163),
#     (5, 0.00020408163),
#     (6, 0.00020408163),
#     (7, 0.00020408163),
#     (8, 0.00020408163),
#     (9, 0.00020408163),
#     (10, 0.00020408163),
#     (11, 0.00020408163),
#     (12, 0.00020408163),
#     (13, 0.00020408163),
#     (14, 0.00020408163),
#     (15, 0.00020408163),
#     (16, 0.00020408163),
#     (17, 0.00020408163),
#     (18, 0.00020408163),
#     (19, 0.00020408163),
#     (20, 0.00020408163),
#     (21, 0.00020408163),
#     (22, 0.00020408163),
#     (23, 0.00020408163),
#     (24, 0.00020408163),
#     (25, 0.00020408163),
#     (26, 0.00020408163),
#     (27, 0.00020408163),
#     (28, 0.00020408163),
#     (29, 0.114917174),
#     (30, 0.00020408163),
#     (31, 0.00020408163),
#     (32, 0.00020408163),
#     (33, 0.00020408163),
#     (34, 0.00020408163),
#     (35, 0.00020408163),
#     (36, 0.00020408163),
#     (37, 0.00020408163),
#     (38, 0.00020408163),
#     (39, 0.8752869),
#     (40, 0.00020408163),
#     (41, 0.00020408163),
#     (42, 0.00020408163),
#     (43, 0.00020408163),
#     (44, 0.00020408163),
#     (45, 0.00020408163),
#     (46, 0.00020408163),
#     (47, 0.00020408163),
#     (48, 0.00020408163),
#     (49, 0.00020408163)]}),
#  ('http://www.omskinform.ru/news/61746',
#   {'_id': '5489df8137a808115d1ee743',
#    'comments': [['совесть у этот шакал нет ни капелька... ага, подбрасывать табун лошадь....\n',
#      0,
#      0],
#     ['он по поддельный ветеринарный справка в сх желанный весь скот вывозить на мясокомбинат.\n',
#      0,
#      0],
#     ['отличный план! долго придумывать тов.ратковский?\n', 1, 2],
#     ['это   давно   все   уже    ясно   что   лошадь   подбрасывать    ,  но   только   не   понятно  здесь    почему   местный   житель    путать   свой   лошадь   с   колхозный ,   наверно   хотять   подменивать   хороший   лошадь   на   старый   и   плохой  ,   а   так   все  здесь   понятный    и   ясный   с   этот   банкротство....\n',
#      0,
#      0],
#     ['не слушать вы этот конкурсный управляющий, я они не один не верить! среди они честный нет! они  думать только о то, чтобы вырывать любой способ  свой огромный з/ тот из банкрот!\n',
#      3,
#      1]],
#    'content': 'Арбитражный управляющий банкротящегося хозяйства заявляет, что кормов для лошадей было достаточно, но их специально морили голодом. Скандал вокруг ЗАО «Роза Люксембург» в Любинском районе области, где под угрозой гибели находился табун лошадей, получил неожиданное развитие. Арбитражный управляющий Владислав Ратковский (на фото справа) заявил, что ослабленные лошади могли быть привезены в «Розу Люксембург» из других мест, чтобы спровоцировать конфликт. Как уже сообщало РИА «Омск-Информ», на прошлой неделе в СМИ попала информация о лошадях, умирающих в Любинском районе . Ослабленные отсутствием корма животные находились на морозе в открытом загоне. Часть животных погибла, остальных в спешном поряд
ях один малыш упал с дерева и ушибся. «Оно практически висит на сучьях, ветер посильнее подует — и оно поедет», - говорит омич, объясняя, почему жильцы, особенно родители с колясками и детьми, опасливо обходят его стороной. Долгое время Максиму не удавалось связаться с руководством компании. Вместо ответа они прислали двух рабочих в нетрезвом состоянии. - Они похихикали, пошутили - предложили обмыть это дело, - рассказал гражданин. - Но сказали, что ничего сделать не могут. После нескольких безуспешных попыток добиться от управляющей компании действий омич решил подавать в суд на\xa0«ЖКХ «Сервис». По его словам, он консультировался с юристами и намерен до конца отстаивать свое право на чистый и безопасный двор. Его инициативу поддерживают пока только несколько соседей. Напомним, что в субботу по городу пронесся шквальный ветер, поваливший не только деревья, но и рекламные щиты, остановки и светофоры. Несмотря на то, что большая часть городских территорий уже очищена от мусора, во многих дворах по-прежнему остаются сучья, стволы и даже целые деревья, вырванные ветром с корнем, как на улице Коммунальной. Разница заключается лишь в отношении омичей к этой проблеме. ',
#    'source': 'http://www.bk55.ru/news/article/32080/',
#    'title': 'Омич хочет судиться с «ЖКХ «Сервис» из-за поваленного дерева',
#    'topics1': [(0, 0.74566853),
#     (1, 9.5238094e-05),
#     (2, 9.5238094e-05),
#     (3, 0.056786675),
#     (4, 9.5238094e-05),
#     (5, 9.5238094e-05),
#     (6, 9.5238094e-05),
#     (7, 9.5238094e-05),
#     (8, 9.5238094e-05),
#     (9, 9.5238094e-05),
#     (10, 9.5238094e-05),
#     (11, 9.5238094e-05),
#     (12, 0.12797391),
#     (13, 9.5238094e-05),
#     (14, 0.065189935),
#     (15, 9.5238094e-05),
#     (16, 9.5238094e-05),
#     (17, 9.5238094e-05),
#     (18, 9.5238094e-05),
#     (19, 9.5238094e-05),
#     (20, 9.5238094e-05),
#     (21, 9.5238094e-05),
#     (22, 9.5238094e-05),
#     (23, 9.5238094e-05),
#     (24, 9.5238094e-05),
#     (25, 9.5238094e-05),
#     (26, 9.5238094e-05),
#     (27, 9.5238094e-05),
#     (28, 9.5238094e-05),
#     (29, 9.5238094e-05),
#     (30, 9.5238094e-05),
#     (31, 9.5238094e-05),
#     (32, 9.5238094e-05),
#     (33, 9.5238094e-05),
#     (34, 9.5238094e-05),
#     (35, 9.5238094e-05),
#     (36, 9.5238094e-05),
#     (37, 9.5238094e-05),
#     (38, 9.5238094e-05),
#     (39, 9.5238094e-05),
#     (40, 9.5238094e-05),
#     (41, 9.5238094e-05),
#     (42, 9.5238094e-05),
#     (43, 9.5238094e-05),
#     (44, 9.5238094e-05),
#     (45, 9.5238094e-05),
#     (46, 9.5238094e-05),
#     (47, 9.5238094e-05),
#     (48, 9.5238094e-05),
#     (49, 9.5238094e-05)],
#    'topics2': [(0, 9.5238094e-05),
#     (1, 9.5238094e-05),
#     (2, 9.5238094e-05),
#     (3, 9.5238094e-05),
#     (4, 9.5238094e-05),
#     (5, 9.5238094e-05),
#     (6, 9.5238094e-05),
#     (7, 9.5238094e-05),
#     (8, 9.5238094e-05),
#     (9, 9.5238094e-05),
#     (29, 0.0002702703),
#     (30, 0.0002702703),
#     (31, 0.0002702703),
#     (32, 0.0002702703),
#     (33, 0.0002702703),
#     (34, 0.0002702703),
#     (35, 0.0002702703),
#     (36, 0.0002702703),
#     (37, 0.0002702703),
#     (38, 0.0002702703),
#     (39, 0.0002702703),
#     (40, 0.0002702703),
#     (41, 0.0002702703),
#     (42, 0.0002702703),
#     (43, 0.0002702703),
#     (44, 0.0002702703),
#     (45, 0.0002702703),
#     (46, 0.0002702703),
#     (47, 0.0002702703),
#     (48, 0.0002702703),
#     (49, 0.0002702703)],
#    'topics2': [(0, 0.00027027028),
#     (1, 0.00027027028),
#     (2, 0.00027027028),
#     (3, 0.00027027028),
#     (4, 0.00027027028),
#     (5, 0.00027027028),
#     (6, 0.00027027028),
#     (7, 0.00027027028),
#     (8, 0.00027027028),
#     (9, 0.00027027028),
#     (10, 0.00027027028),
#     (11, 0.00027027028),
#     (12, 0.00027027028),
#     (13, 0.00027027028),
#     (14, 0.09995724),
#     (15, 0.00027027028),
#     (16, 0.00027027028),
#     (17, 0.00027027028),
#     (18, 0.00027027028),
#     (19, 0.00027027028),
#     (20, 0.00027027028),
#     (21, 0.00027027028),
#     (22, 0.00027027028),
#     (23, 0.00027027028),
#     (24, 0.00027027028),
#     (25, 0.09512527),
#     (26, 0.00027027028),
#     (27, 0.00027027028),
#     (28, 0.00027027028),
#     (29, 0.00027027028),
#     (30, 0.00027027028),
#     (31, 0.00027027028),
#     (32, 0.00027027028),
#     (33, 0.00027027028),
#     (34, 0.00027027028),
#     (35, 0.00027027028),
#     (36, 0.00027027028),
#     (37, 0.00027027028),
#     (38, 0.00027027028),
#     (39, 0.00027027028),
#     (40, 0.00027027028),
#     (41, 0.00027027028),
#     (42, 0.00027027028),
#     (43, 0.00027027028),
#     (44, 0.00027027028),
#     (45, 0.00027027028),
#     (46, 0.00027027028),
#     (47, 0.7922148),
#     (48, 0.00027027028),
#     (49, 0.00027027028)]}),
#  ('http://www.bk55.ru/news/article/37799/',
#   {'_id': '5489d18037a808115d1e6cb2',
#    'comments': [['зашуршать в карман бабло\n', 0, 0],
#     ['даа, булка вкусный там быть…\n', 1, 0],
#     ['этот ремонт мы производить за счет собственный средство\n', 0, 0],
#     ['автор новость преподноситься как негативный. не понимать. мы пытаться показывать, что делать ремонт больница- плохо?! то более не за счет бюджет, а на средство, получать от платный услуга. лично я бы спасибо сказать администрация окб. давать бог чтобы больший количество больница так выглядеть как снаружи так и внутри. или автор приятно лечиться среди растрескать и облупливать стена?\n',
#      2,
#      1],
#     ['почему больница полежаев, а не имя полежаев? непорядочек!\n', 1, 1],
#     ['окб! как вы "доставать " со свой бесконечный прожект! к вы больница зайти страшно- вы весь как зомби.если бы вы заниматься самоуничтожение только в рамка свой больница, то бог с вы, но ваш "новшество" навязываться повсеместный. вы как раковый опухоль. когда вы наконец-то переставать заниматься свой многолетний дурацкий безумный проект, который служить лазейка для отбор деньги от реальный специалист?! от вы весь зараза!\n',
#      -2,
#      -1],
#     ['лишь бы фамилия известный прицеплять, для читаемость. гнусь. что тогда евромеда не называть "клиника шуголь"? много основание!\n',
#      1,
#      1]],
#    'content': 'Отдельно стоящее помещение, где раньше торговали продуктами, отремонтируют и приспособят под нужды лечебного учреждения. Появилась информация, что Омская областная клиническая больница, главным врачом которой является Константин Полежаев, намерена «неприлично потратиться» на ремонт здания на Березовой, 3, где ранее располагался продуктовый магазин. – Основная часть площадей в одноэтажном отдельно стоящем здании длительное время находилась в аренде, здесь продавались продукты. Теперь\xa0 арендатор отказался от части помещений, и после их реконструкции мы намерены разместить здесь инженерные службы больницы, – цитирует РИА «Омск-Информ» заместителя главного врача по хозяйственным вопросам БУЗОО «Омская областная клиническая больница» Виктора Дынника. Как сообщает портал закупок, работы первоначально планирует вести ООО «Альпинизм Вентиляция Кондиционирование «Чистый воздух». Примечательно, что первоначально на участие в конкурсе претендовали 7 компаний, но только две из них прошли во второй тур. Второй претендент на дорогостоящие работы – ООО «РегионСтройСервисАвтоматика». Однако «Чистый воздух» предложила наименьшую цену в 1,492 миллиона рублей. Больница Полежаева уже заключила договор с подрядчиком. За 40 дней компания обновит помещения площадью 85 квадратных метров: проведет общестроительные, сантехнические, вентиляционные, электромонтажные работы, а также установит пожарную и охранную сигнализации. ',
#    'source': 'http://www.bk55.ru/news/article/37799/',
#    'title': 'Больница Полежаева перестроит магазин под инженерные службы за 1,5 миллиона',
#    'topics1': [(0, 0.7188254),
#     (1, 0.00014285714),
#     (2, 0.00014285714),
#     (3, 0.00014285714),
#     (4, 0.00014285714),
#     (5, 0.00014285714),
#     (6, 0.00014285714),
#     (7, 0.00014285714),
#     (8, 0.00014285714),
#     (9, 0.00014285714),
#     (10, 0.00014285714),
#     (11, 0.00014285714),
#     (12, 0.00014285714),
#     (13, 0.00014285714),
#     (14, 0.00014285714),
#     (15, 0.19893277),
#     (16, 0.00014285714),
#     (17, 0.00014285714),
#     (18, 0.00014285714),
#     (19, 0.00014285714),
#     (20, 0.00014285714),
#     (21, 0.00014285714),
#     (22, 0.00014285714),
#     (23, 0.00014285714),
#     (24, 0.00014285714),
#     (25, 0.00014285714),
#     (26, 0.00014285714),
#     (27, 0.00014285714),
#     (28, 0.00014285714),
#     (29, 0.00014285714),
#     (30, 0.00014285714),
#     (31, 0.00014285714),
#     (32, 0.00014285714),
#     (33, 0.00014285714),
#     (34, 0.00014285714),
#     (35, 0.00014285714),
#     (36, 0.00014285714),
#     (37, 0.00014285714),
#     (38, 0.00014285714),
#     (39, 0.00014285714),
#     (40, 0.029729502),
#     (41, 0.045940857),
#     (42, 0.00014285714),
#     (43, 0.00014285714),
#     (44, 0.00014285714),
#     (45, 0.00014285714),
#     (46, 0.00014285714),
#     (47, 0.00014285714),
#     (48, 0.00014285714),
#     (49, 0.00014285714)],
#    'topics2': [(0, 0.00014285716),
#     (1, 0.00014285716),
#     (2, 0.00014285716),
#     (3, 0.00014285716),
#     (4, 0.00014285716),
#     (5, 0.00014285716),
#     (6, 0.00014285716),
#     (7, 0.00014285716),
#     (8, 0.00014285716),
#     (9, 0.00014285716),
#     (10, 0.00014285716),
#     (11, 0.00014285716),
#     (12, 0.99300003),
#     (13, 0.00014285716),
#     (14, 0.00014285716),
#     (15, 0.00014285716),
#     (16, 0.00014285716),
#     (17, 0.00014285716),
#     (18, 0.00014285716),
#     (19, 0.00014285716),
#     (20, 0.00014285716),
#     (21, 0.00014285716),
#     (22, 0.00014285716),
#     (23, 0.00014285716),
#     (24, 0.00014285716),
#     (25, 0.00014285716),
#     (26, 0.00014285716),
#     (27, 0.00014285716),
#     (28, 0.00014285716),
#     (29, 0.00014285716),
#     (30, 0.00014285716),
#     (31, 0.00014285716),
#     (32, 0.00014285716),
#     (33, 0.00014285716),
#     (34, 0.00014285716),
#     (35, 0.00014285716),
#     (36, 0.00014285716),
#     (37, 0.00014285716),
#     (38, 0.00014285716),
#     (39, 0.00014285716),
#     (40, 0.00014285716),
#     (41, 0.00014285716),
#     (42, 0.00014285716),
#     (43, 0.00014285716),
#     (44, 0.00014285716),
#     (45, 0.00014285716),
#     (46, 0.00014285716),
#     (47, 0.00014285716),
#     (48, 0.00014285716),
#     (49, 0.00014285716)]}),
#  ('http://www.bk55.ru/news/article/37699/',
#   {'_id': '5489d18837a808115d1e6d01',
#    'comments': [['реальный инфляция для народ — 30–40%\n', 0, 0]],
#    'content': 'По оценкам аналитиков, на показатель влияют продуктовые санкции России. Министерство экономического развития РФ повысило прогноз по инфляции на 2014 год до 7-7,5%, а на 2015 год - до 6-7%. Об этом сообщает Интерфакс со ссылкой на источник в финансово-экономическом блоке правительства. Ранее ведомство заявляло о чуть менее высоких показателях темпа роста инфляции на эти годы: в 2014 - 5,5-6,5%, а в 2015 - 4,5-5,5%. Аналитики, в свою очередь, констатировали, что из-за подорожания продуктов после эмбарго на импорт ряда продовольствия из стран ЕС, Канады, Австралии, Норвегии и США, инфляция может существенно превысить прогноз Минэкономиразвития (МЭР), пишет РБК. «Опасаясь дефицита и удорожания поставок в будущем, продавцы закладывают эти риски в текущие цены. В результате в августе инфляция может быть существенно выше прогноза МЭР (0,1%), а говорить о дефляции уже не приходится», - цитирует источник специалистов Райффайзенбанка. По данным Росстата, резкий рост цен зафиксирован на продукты питания, на импорт которых из ряда стран с 7 августа запрещен. Больше всего подорожала курица и свинина. Также начали расти цены на яблоки. ',
#    'source': 'http://www.bk55.ru/news/article/37699/',
#    'title': 'Минэкономики повысило прогноз по инфляции на этот год до 7 процентов',
#    'topics1': [(0, 0.6762751),
#     (1, 0.00017857144),
#     (2, 0.00017857144),
#     (3, 0.00017857144),
#     (4, 0.00017857144),
#     (5, 0.00017857144),
#     (6, 0.00017857144),
#     (7, 0.00017857144),
#     (8, 0.00017857144),
#     (9, 0.00017857144),
#     (10, 0.00017857144),
#     (11, 0.00017857144),
#     (12, 0.00017857144),
#     (13, 0.00017857144),
#     (14, 0.00017857144),
#     (15, 0.00017857144),
#     (16, 0.00017857144),
#     (17, 0.00017857144),
#     (18, 0.00017857144),
#     (19, 0.00017857144),
#     (20, 0.00017857144),
#     (21, 0.00017857144),
#     (22, 0.00017857144),
#     (23, 0.00017857144),
#     (24, 0.00017857144),
#     (25, 0.00017857144),
#     (26, 0.00017857144),
#     (27, 0.00017857144),
#     (28, 0.00017857144),
#     (29, 0.00017857144),
#     (30, 0.00017857144),
#     (31, 0.098323874),
#     (32, 0.21700814),
#     (33, 0.00017857144),
#     (34, 0.00017857144),
#     (35, 0.00017857144),
#     (36, 0.00017857144),
#     (37, 0.00017857144),
#     (38, 0.00017857144),
#     (39, 0.00017857144),
#     (40, 0.00017857144),
#     (41, 0.00017857144),
#     (42, 0.00017857144),
#     (43, 0.00017857144),
#     (44, 0.00017857144),
#     (45, 0.00017857144),
#     (46, 0.00017857144),
#     (47, 0.00017857144),
#     (48, 0.00017857144),
#     (49, 0.00017857144)],
#    'topics2': [(0, 0.00017857144),
#     (1, 0.00017857144),
#     (2, 0.00017857144),
#     (3, 0.00017857144),
#     (4, 0.00017857144),
#     (5, 0.00017857144),
#     (6, 0.00017857144),
#     (7, 0.00017857144),
#     (8, 0.00017857144),
#     (9, 0.053539883),
#     (10, 0.00017857144),
#     (11, 0.00017857144),
#     (12, 0.049026642),
#     (13, 0.00017857144),
#     (14, 0.00017857144),
#     (15, 0.00017857144),
#     (16, 0.00017857144),
#     (17, 0.00017857144),
#     (18, 0.00017857144),
#     (19, 0.00017857144),
#     (20, 0.00017857144),
#     (21, 0.00017857144),
#     (22, 0.00017857144),
#     (23, 0.00017857144),
#     (24, 0.00017857144),
#     (25, 0.00017857144),
#     (26, 0.00017857144),
#     (27, 0.00017857144),
#     (28, 0.00017857144),
#     (29, 0.00017857144),
#     (30, 0.00017857144),
#     (31, 0.00017857144),
#     (32, 0.00017857144),
#     (33, 0.00017857144),
#     (34, 0.00017857144),
#     (35, 0.00017857144),
#     (36, 0.00017857144),
#     (37, 0.00017857144),
#     (38, 0.00017857144),
#     (39, 0.00017857144),
#     (40, 0.00017857144),
#     (41, 0.00017857144),
#     (42, 0.00017857144),
#     (43, 0.8182041),
#     (44, 0.00017857144),
#     (45, 0.00017857144),
#     (46, 0.00017857144),
#     (47, 0.00017857144),
#     (48, 0.0710151),
#     (49, 0.00017857144)]}),
#  ('http://www.bk55.ru/news/article/25514/',
#   {'_id': '5489d66c37a808115d1e9625',
#    'comments': [['выговор он с занесение в грудной клетка. кто крайний в очередь на пробивание?\n',
#      -1,
#      0],
#     ['ага, а где быть этот клоун, когда разорять учебный хозяйство сельхоз и ветеринарка? учхоз 1 в камышловка и учхоз 2 в харламовый-лобковый-камышиный?\n',
#      0,
#      0],
#     ['ну насмешить, штраф в 40 тысяча, он и не почувствовать никакой наказание, можно и далеко не кормить 15 лошадка, 5 из который погибать . это должный быть не просто административка, нужно такой наказывать более весомо, чтоб другой быть не повадно. штраф в сша накладывать, даже за то, что вовремя собака ветиринар не показывать.\n',
#      -4,
#      -1],
#     ['это обычный рейдерский захват, , , деревня рядом с город, обонкрощать и купить она за копейка\n',
#      0,
#      0],
#     ['да для он это даже не семечко\n', 0, 0],
#     ['\\" ранее становиться известно, что в этот разорять хозяйство из-за недосмотр сотрудник гибнуть лошадь.\\" читать внимательно! арбитражный управляющий они кормить и не должный! а сотрудник теперь премия лишать и ущерб через суд удерживать. а еще бы этот виновный сотрудник привлекать за жестокий обращение с животное. тогда все вставать на свой место.\n',
#      -2,
#      -2],
#     ['ага! умник бессердечный! какой же мука вынести животное перед смерть! весь деревня сжигать напалм, и хозяин туда же, ибо это уже не человек, а зверь! оборотень! жалко быть подкармливать, а потом бить вовсе колокол! потом удивляться, откуда у мы браться убийца… вот они…\n',
#      -3,
#      -2],
#     ['а почему эрлих с целый минсельхоз молчать? или минсельхоз работать чисто статист?\n',
#      0,
#      0]],
#    'content': 'Власти отреагировали на резонансную историю в Любинском районе с гибелью лошадей - конкурсный управляющий обанкротившегося хозяйства понесет за это наказание. Правительство региона сегодня отчиталось, что «по поручению и под личным контролем губернатора Омской области Виктора  Назарова приняты меры по спасению лошадей в обанкротившемся фермерском хозяйстве им. Розы Люксембург в Любинском районе, а также проводится всесторонняя  проверка ситуации в этом хозяйстве». Специалисты регионального \xa0минсельхозпрода провели ряд экстренных совещаний и проверок фактов  ненадлежащего содержания лошадей в деревне Ровная Поляна. Установлено, что  конкурсный управляющий Владислав Ратковский не обеспечил кормление и уход за лошадьми,  что привело к истощению и падежу нескольких животных. На данный момент  оставшиеся в живых лошади общественного поголовья вывезены в хозяйство  Марьяновского района. Сейчас животные поставлены на карантин и обеспечены  кормами, водой и необходимым уходом. Главное управление ветеринарии Омской  области на Ратковского наложило штраф в 40 тысяч рублей. Ранее стало известно, что в этом разоренном хозяйстве из-за недосмотра сотрудников гибнут лошади. ',
#    'source': 'http://www.bk55.ru/news/article/25514/',
#    'title': 'Оставшихся в «Розе Люксембург» лошадей откормят, а управляющего оштрафуют',
#    'topics1': [(0, 0.6755906),
#     (1, 0.00016806723),
#     (2, 0.00016806723),
#     (3, 0.00016806723),
#     (4, 0.00016806723),
#     (5, 0.00016806723),
#     (6, 0.00016806723),
#     (7, 0.00016806723),
#     (8, 0.00016806723),
#     (9, 0.00016806723),
#     (10, 0.00016806723),
#     (11, 0.00016806723),
#     (12, 0.00016806723),
#     (13, 0.00016806723),
#     (14, 0.00016806723),
#     (15, 0.00016806723),
#     (16, 0.00016806723),
#     (17, 0.00016806723),
#     (18, 0.00016806723),
#     (19, 0.00016806723),
#     (20, 0.00016806723),
#     (21, 0.00016806723),
#     (22, 0.00016806723),
#     (23, 0.03220071),
#     (24, 0.00016806723),
#     (25, 0.00016806723),
#     (26, 0.00016806723),
#     (27, 0.00016806723),
#     (28, 0.00016806723),
#     (29, 0.00016806723),
#     (30, 0.00016806723),
#     (31, 0.00016806723),
#     (32, 0.00016806723),
#     (33, 0.00016806723),
#     (34, 0.00016806723),
#     (35, 0.00016806723),
#     (36, 0.00016806723),
#     (37, 0.00016806723),
#     (38, 0.00016806723),
#     (39, 0.00016806723),
#     (40, 0.00016806723),
#     (41, 0.00016806723),
#     (42, 0.00016806723),
#     (43, 0.00016806723),
#     (44, 0.28430957),
#     (45, 0.00016806723),
#     (46, 0.00016806723),
#     (47, 0.00016806723),
#     (48, 0.00016806723),
#     (49, 0.00016806723)],
#    'topics2': [(0, 0.00016806723),
#     (1, 0.00016806723),
#     (2, 0.00016806723),
#     (3, 0.00016806723),
#     (4, 0.00016806723),
#     (5, 0.00016806723),
#     (6, 0.00016806723),
#     (7, 0.00016806723),
#     (8, 0.00016806723),
#     (9, 0.00016806723),
#     (10, 0.00016806723),
#     (11, 0.00016806723),
#     (12, 0.00016806723),
#     (13, 0.00016806723),
#     (14, 0.30648115),
#     (15, 0.00016806723),
#     (16, 0.00016806723),
#     (17, 0.00016806723),
#     (18, 0.00016806723),
#     (19, 0.00016806723),
#     (20, 0.00016806723),
#     (21, 0.00016806723),
#     (22, 0.00016806723),
#     (23, 0.00016806723),
#     (24, 0.00016806723),
#     (25, 0.00016806723),
#     (26, 0.00016806723),
#     (27, 0.00016806723),
#     (28, 0.11547971),
#     (29, 0.00016806723),
#     (30, 0.00016806723),
#     (31, 0.00016806723),
#     (32, 0.00016806723),
#     (33, 0.00016806723),
#     (34, 0.00016806723),
#     (35, 0.00016806723),
#     (36, 0.00016806723),
#     (37, 0.00016806723),
#     (38, 0.57013994),
#     (39, 0.00016806723),
#     (40, 0.00016806723),
#     (41, 0.00016806723),
#     (42, 0.00016806723),
#     (43, 0.00016806723),
#     (44, 0.00016806723),
#     (45, 0.00016806723),
#     (46, 0.00016806723),
#     (47, 0.00016806723),
#     (48, 0.00016806723),
#     (49, 0.00016806723)]}),
#  ('http://gorod55.ru/news/article/85fcd664-8a4d-46f0-a311-bf7aa73df10a',
#   {'_id': '5489d96037a808115d1eae98',
#    'comments': [],
#    'content': 'Российский телеком-оператор «Дом.ru» предлагает всем телезрителям подключиться к современному цифровому телевидению «Дом.ru TV» на выгодных условиях. Тех, кто смотрит аналоговое ТВ, ждет специальная цена на оборудование (ТВ-приставку или CAM-модуль) и 2 месяца пользования услугой. Абоненты кабельного телевидения «Дом.ru» также могут перейти на более современный формат телесмотрения. Все пользователи «Дом.ru TV» могут каждый месяц смотреть дополнительные пакеты каналов и получать другие бонусы без дополнительной платы – с 7 мая по 6 июня можно будет смотреть лучшие мировые сериалы на канале «Amedia Premium HD». «Большинство продаваемых телевизоров предполагает возможность просмотра цифровых каналов. «Дом.ru TV» в пакете с интернетом позволяет Абонентам использовать эту возможность – просматривать телеконтент в формате высокой четкости, пользоваться популярными интернет-сервисами с экрана телевизора, а также получать высокую скорость доступа в интернет», – отмечает директор филиала «Дом.ru» в Омске Игорь Верещагин. «Дом.ru TV» поэтапно запущено в городах присутствия Компании в 2012-2013 гг. «Дом.ru» активно работает над развитием инновационной услуги, формируя оптимальное предложение HD-каналов, сервисов и интернет-приложений. Пользователям услуги HD-телевидения «Дом.ru TV» сегодня доступны 159 цифровых каналов, в том числе 52 в HD-формате – это максимум на рынке платного ТВ России. Подробная информация о предложении - на сайте domru.ru и по телефону 8-800-333-7000 (круглосуточно, бесплатно). На правах рекламы',
#     (41, 0.00013157896),
#     (42, 0.00013157896),
#     (43, 0.00013157896),
#     (44, 0.00013157896),
#     (45, 0.00013157896),
#     (46, 0.00013157896),
#     (47, 0.12529297),
#     (48, 0.00013157896),
#     (49, 0.00013157896)]}),
#  ('http://www.omskinform.ru/news/61660',
#   {'_id': '5489df8837a808115d1ee78c',
#    'comments': [['в стойло он и не кормить\n', 0, 0],
#     ['40 тысяча за такой зверство? ну давать он еще по голова погладить и пальчик погрозить, хотя бы. мир сходить с ум.\n',
#      0,
#      -1],
#     ['что для он этот штраф 40 тысяча,один лошадь ЧК стоять не мало 100 тысяча,так посчитать бы жизнь загубить лошадь и делать штраф исходить из стоимость каждый.такой как этот управляющий местон в стойло а за решетка.\n',
#      0,
#      0],
#     ['пусть  этот загубить лошадка сниться , тот кто  виновный в их гибель\n',
#      -4,
#      0],
#     ['он-то в стойло, а где быть руководство управление с/х район, глава. я думать, что прокуратура расставлять точка над i.\n',
#      0,
#      0]],
#    'content': 'ГУ ветеринарии Омской области оштрафовало на 40 тысяч рублей конкурсного управляющего Владислава Ратковского, который не обеспечил кормление и уход за лошадьми. Региональные власти назвали виновного в гибели лошадей в ЗАО «Роза Люксембург». Сегодня стало известно, что ГУ ветеринарии Омской области оштрафовало на 40 тысяч рублей конкурсного управляющего Владислава Ратковского (на фото) – именно он, по мнению чиновников, не обеспечил кормление и уход за лошадьми. Как уже сообщало РИА «Омск-Информ», новые собственники имущества банкротящегося ЗАО бросили животных без корма в загоне под открытым небом. По предварительным данным, из 20 лошадей трое животных погибли, одну лошадь зарезали, еще одного жеребенка увезли в неизвестном направлении. Остальные лошади были перевезены в деревню Орловка Марьяновского района. После того, как эти факты были обнародованы СМИ, губернатор Виктор Назаров потребовал от чиновников принять экстренные меры по спасению лошадей в обанкротившемся фермерском хозяйстве, а также провести всестороннюю проверку ситуации в ЗАО «Роза Люксембург». Уже прошел ряд экстренных совещаний с участием специалистов регионального Минсельхозпрода, выявлены факты ненадлежащего содержания лошадей. – Установлено, что конкурсный управляющий Ратковский не обеспечил кормление и уход за лошадьми, что привело к истощению и падежу нескольких животных, – говорится в заявлении правительства Омской области. – \xa0Главным управлением ветеринарии Омской области на конкурсного управляющего Владислава Ратковского наложен штраф в размере 40 тыс. рублей. Кроме того, материалы расследования направлены в прокуратуру Омской области для проведения внеплановой проверки для определения и наказания виновных лиц. На данный момент оставшиеся в живых лошади вывезены в хозяйство Марьяновского района. Сейчас животные поставлены на карантин и обеспечены кормами и водой и необходимым уходом.',
#    'source': 'http://www.omskinform.ru/news/61660',
#    'title': 'Область назвала виновного в гибели лошадей из «Розы Люксембург» \xa0\xa0[ФОТО]',
#    'topics1': [(0, 0.67201144),
#     (1, 0.00010582011),
#     (2, 0.00010582011),
#     (3, 0.00010582011),
#     (4, 0.00010582011),
#     (5, 0.00010582011),
#     (6, 0.00010582011),
#     (7, 0.00010582011),
#     (8, 0.00010582011),
#     (9, 0.00010582011),
#     (10, 0.00010582011),
#     (11, 0.00010582011),
#     (12, 0.00010582011),
#     (13, 0.00010582011),
#     (14, 0.00010582011),
#     (15, 0.00010582011),
#     (16, 0.00010582011),
#     (17, 0.00010582011),
#     (18, 0.00010582011),
#     (19, 0.00010582011),
#     (20, 0.00010582011),
#     (21, 0.00010582011),
#     (22, 0.00010582011),
#     (23, 0.00010582011),
#     (24, 0.00010582011),
#     (25, 0.00010582011),
#     (26, 0.00010582011),
#     (27, 0.00010582011),
#     (28, 0.00010582011),
#     (29, 0.00010582011),
#     (30, 0.00010582011),
#     (31, 0.00010582011),
#     (32, 0.00010582011),
#     (33, 0.00010582011),
#     (34, 0.00010582011),
#     (35, 0.00010582011),
#     (36, 0.00010582011),
#     (37, 0.00010582011),
#     (38, 0.00010582011),
#     (39, 0.00010582011),
#     (40, 0.00010582011),
#     (41, 0.00010582011),
#     (42, 0.00010582011),
#     (43, 0.00010582011),
#     (44, 0.15961333),
#     (45, 0.00010582011),
#     (46, 0.00010582011),
#     (47, 0.00010582011),
#     (48, 0.16340165),
#     (49, 0.00010582011)],
#    'topics2': [(0, 0.0001058201),
#     (1, 0.0001058201),
#     (2, 0.0001058201),
#     (3, 0.0001058201),
#     (4, 0.0001058201),
#     (5, 0.0001058201),
#     (6, 0.0001058201),
#     (7, 0.0001058201),
#     (8, 0.0001058201),
#     (9, 0.0001058201),
#     (10, 0.0001058201),
#     (11, 0.0001058201),
#     (12, 0.07431234),
#     (13, 0.0001058201),
#     (14, 0.23987193),
#     (15, 0.0001058201),
#     (16, 0.0001058201),
#     (17, 0.0001058201),
#     (18, 0.0001058201),
#     (19, 0.0001058201),
#     (20, 0.0001058201),
#     (21, 0.0001058201),
#     (22, 0.0001058201),
#     (23, 0.0001058201),
#     (24, 0.0001058201),
#     (25, 0.0001058201),
#     (26, 0.0001058201),
#     (27, 0.0001058201),
#     (28, 0.0001058201),
#     (29, 0.0001058201),
#     (30, 0.0001058201),
#     (31, 0.0001058201),
#     (32, 0.0001058201),
#     (33, 0.0001058201),
#     (34, 0.0001058201),
#     (35, 0.0001058201),
#     (36, 0.0001058201),
#     (37, 0.0001058201),
#     (38, 0.68084216),
#     (39, 0.0001058201),
#     (40, 0.0001058201),
#     (41, 0.0001058201),
#     (42, 0.0001058201),
#     (43, 0.0001058201),
#     (44, 0.0001058201),
#     (45, 0.0001058201),
#     (46, 0.0001058201),
#     (47, 0.0001058201),
#     (48, 0.0001058201),
#     (49, 0.0001058201)]}),
#  ('http://www.omskinform.ru/news/61537',
#   {'_id': '5489df9437a808115d1ee7f6',
#    'comments': [['господи, да что же мы за человек такой жестокий, "без честь, без совесть"? до слеза больно и обидно... а этот фермер мочь бы обращаться к казах или цыган за помощь. человек этот национальность никогда не оставлять в беда "брат наш меньший".\n',
#      0,
#      -1],
#     ['мочь доходить? а что откупиться ? во весь цивилизованный мир этот издевательство над животный  , повлечь бы одевание наручник и лишение свобода . смотреть больно , на мучение лошадка , почему же человек такой изверг\n',
#     ['деревенский парень , зайти в мегафон\n', 0, 0],
#     ['как понимать сам LTE=4G следующий поколение связь который позволять оператор уменьшать затрата на обеспечение передача данные и увеличивать прибыль - айда все за LTE телефон!!!\n',
#      1,
#      1],
#     ['LTE сеть быть у мегафон.\n', 0, 0],
#     ['ну вот, мтс стараться-стараться, а лавра все равный мегафон))))))) мтс становиться все плохо и плохо, хоть и кричать о свой величие\n',
#      -1,
#      0]],
#    'content': 'Сотовый оператор МТС открыл в Омске продажи LTE-смартфона под собственным брендом. Как пояснили в пресс-службе «МТС-Сибирь», до конца года в Омске также будут доступны LTE-планшеты. Оба устройства работают в сетях LTE и 3G и могут выходить в интернет на скорости до 100 Мбит/с. Планшет продается по цене 9990 руб., смартфон — 9490 руб. Смартфон МТС 978 отличается тонкостью и легкостью (7,45 мм, 110 г). Он базируется на платформе Android 4.2 Jelly Bean. Аппарат оснащен ярким 4,7-дюймовым IPS-дисплеем разрешением 1280x720 и камерой с разрешением 8 МП и 4-кратным зумом. LTE-планшет МТС 1078 работает на операционной системе Android 4.1, оснащен двухъядерным процессором частотой 1,6 ГГц и 1 ГБ оперативной памяти, емкостным IPS-дисплеем с диагональю 7 дюймов и разрешением 1280x800, а также 2 фотокамерами разрешением до 3 МП. Встроенная память составляет 4 ГБ и имеет возможность расширения. При этом отметим, у компании МТС сейчас нет сети LTE в Омске, оператор планирует ее запуск в 2014 году. ',
#    'source': 'http://ngs55.ru/news/1524728/view/',
#    'title': 'МТС открыли продажи собственного LTE-смартфона',
#    'topics1': [(0, 0.5101645),
#     (1, 0.00018018018),
#     (2, 0.21517247),
#     (3, 0.00018018018),
#     (4, 0.00018018018),
#     (5, 0.00018018018),
#     (6, 0.00018018018),
#     (7, 0.00018018018),
#     (8, 0.00018018018),
#     (9, 0.00018018018),
#     (10, 0.00018018018),
#     (11, 0.00018018018),
#     (12, 0.00018018018),
#     (13, 0.00018018018),
#     (14, 0.00018018018),
#     (15, 0.00018018018),
#     (16, 0.00018018018),
#     (17, 0.00018018018),
#     (18, 0.00018018018),
#     (19, 0.00018018018),
#     (20, 0.00018018018),
#     (21, 0.00018018018),
#     (22, 0.00018018018),
#     (23, 0.00018018018),
#     (24, 0.00018018018),
#     (25, 0.00018018018),
#     (26, 0.00018018018),
#     (27, 0.05770979),
#     (28, 0.00018018018),
#     (29, 0.00018018018),
#     (30, 0.00018018018),
#     (31, 0.00018018018),
#     (32, 0.00018018018),
#     (33, 0.13012344),
#     (34, 0.00018018018),
#     (35, 0.00018018018),
#     (36, 0.00018018018),
#     (37, 0.00018018018),
#     (38, 0.00018018018),
#     (39, 0.00018018018),
#     (40, 0.00018018018),
#     (41, 0.00018018018),
#     (42, 0.00018018018),
#     (43, 0.00018018018),
#     (44, 0.00018018018),
#     (45, 0.07872172),
#     (46, 0.00018018018),
#     (47, 0.00018018018),
#     (48, 0.00018018018),
#     (49, 0.00018018018)],
#    'topics2': [(0, 0.00018018017),
#     (1, 0.00018018017),
#     (2, 0.00018018017),
#     (3, 0.1467287),
#     (4, 0.4104471),
#     (5, 0.00018018017),
#     (6, 0.00018018017),
#     (7, 0.00018018017),
#     (8, 0.00018018017),
#     (9, 0.00018018017),
#     (10, 0.00018018017),
#     (11, 0.00018018017),
#     (12, 0.00018018017),
#     (13, 0.00018018017),
#     (14, 0.00018018017),
#     (15, 0.00018018017),
#     (16, 0.00018018017),
#     (17, 0.00018018017),
#     (18, 0.00018018017),
#     (19, 0.00018018017),
#     (20, 0.00018018017),
#     (21, 0.00018018017),
#     (22, 0.00018018017),
#     (23, 0.00018018017),
#     (24, 0.00018018017),
#     (25, 0.00018018017),
#     (26, 0.11522313),
#     (27, 0.00018018017),
#     (28, 0.00018018017),
#     (29, 0.00018018017),
#     (30, 0.00018018017),
#     (31, 0.00018018017),
#     (32, 0.29951194),
#     (33, 0.00018018017),
#     (34, 0.00018018017),
#     (35, 0.00018018017),
#     (36, 0.00018018017),
#     (37, 0.00018018017),
#     (38, 0.00018018017),
#     (39, 0.00018018017),
#     (40, 0.00018018017),
#     (41, 0.00018018017),
#     (42, 0.00018018017),
#     (43, 0.00018018017),
#     (44, 0.00018018017),
#     (45, 0.00018018017),
#     (46, 0.00018018017),
#     (47, 0.00018018017),
#     (48, 0.019981032),
#     (49, 0.00018018017)]}),
#  ('http://www.omskinform.ru/news/59959',
#   {'_id': '5489e02a37a808115d1eed2b',
#    'comments': [['ню-ню...))) что-то друг вы перепутывать, написать, что кокорин славиться свой креативность... или постесняться написать другой, более точный слово, а точно "славиться свой дурость"!!!\n',
#      1,
#      -2],
#     ['это не креативность, а дурость - теряться таинство праздник\n', 2, -1],
#     ['с каждый год елка устанавливать все рано, а убирать все поздно. а зачем она вообще убирать? у кокорин ведь каждый день - праздник! такой как он новый год встречать на зона, а он до сей пора  на свобода и еще в почет.\n',
#      -2,
#      1],
#     ['опять вранье, у атриум давно стоить, но не наряжать...\n', -2, 0],
#     ['тут   согласный , не  ранавато-ли   елка   ставить  ,  но   здесь  нюанс   один   скрывать    ,  что   она   наряжать   еще   долго   не  быть  ...\n',
#      1,
#      0]],
#    'content': 'Возле торгового центра «Каскад» устанавливают первую в городе новогоднюю елку. Это место давно славится ранним появлением лесных красавиц. Напротив торгово-выставочного центра «Каскад» прямо сейчас идет установка новогодней елки. Традиционно\xa0лесная красавица\xa0 появляется на этом месте задолго до начала новогодних праздников. Но в этот раз елка появилась даже раньше, чем в прошлом году. К слову, прошлогодний сюрприз для омичей «Каскад» установил в середине октября. Владелец этого торгового центра Валерий Кокорин , уже давно отличился своей креативностью в преддверии больших праздников. В прошлом году примерно в это же время у ТЦ «Континент», также принадлежащему Кокорину, елка появилась примерно в эти же дни. Рано установленная елка отметит с омичами все праздники, предшествующие Новому году, а также праздники после 1 января 2014 года. Обычно «кокоринская елка», как уже давно окрестили ее омичи, стоит примерно до середины марта. Пока что елку только устанавливают, а когда ее будут наряжать, неизвестно. Но уже сейчас омичи, проходящие мимо торгового центра, удивлены столь ранним появлением дерева и с удовольствием фотографируют процесс установки, чтобы позже поделиться этой «новогодней» новостью со своими друзьями.',
#     (49, 0.00016393443)]}),
#  ('http://www.omskinform.ru/news/61590',
#   {'_id': '5489df8f37a808115d1ee7ca',
#    'comments': [['"возбуждать дело.... проводиться проверка... быть решать вопрос о необходимость принятие мера..." а остальной лошадь тот время продолжать голодать и гибнуть?\n',
#      -1,
#      0],
#     ['а почему ни один слово о сам лашадь? как они там? перевозить ли в ветеринарка или там же на мороз? или это не так важно, как состригать штраф?\n',
#      0,
#      0],
#     ['исправлять фактический ошибка: не ровный долина, а ровный поляна!\n',
#      -2,
#      1],
#     ['весь лошадь умирать , достаточно взглядывать на внешний управляющий , юрист на мерс.\n',
#      -2,
#      0]],
#    'content': 'По факту гибели лошадей в ЗАО «Роза Люксембург» возбуждено уголовное дело. Прокуратура намерена найти тех, кто бросил животных на произвол судьбы. Прокуратура Любинского района организовала проверку по факту гибели трех лошадей на территории закрытого акционерного общества «Роза Люксембург» Любинского района. Напомним, что в начале этой недели РИА «Омск-Информ» рассказывало о том , что в деревне Ровная Долина на открытой площадке\xa0погибает целый табун лошадей. Около 20 животных, принадлежавших банкротящемуся ЗАО «Роза Люксембург», оказались брошены и начали гибнуть из-за отсутствия корма и низких температур. В результате проверки, сегодня, 5 декабря, прокурором было возбуждено уголовное дело по ч. 1 ст. 245 УК РФ (жестокое обращение с животными, повлекшее их гибель). Кроме того, в настоящее время прокуратурой проводится проверка соблюдения законодательства о банкротстве закрытого акционерного общества «Роза Люксембург», по результатам которой будет решен вопрос о необходимости принятия мер прокурорского реагирования, а также дана оценка действиям должностных лиц, ответственных за сохранность имущества этого предприятия. Ход проверки находится на особом контроле прокурора Любинского района.',
#    'source': 'http://www.omskinform.ru/news/61590',
#    'title': 'Гибель лошадей в Омской области переросла в уголовное дело',
#    'topics1': [(0, 0.5068746),
#     (1, 0.00015384617),
#     (2, 0.00015384617),
#     (3, 0.00015384617),
#     (4, 0.00015384617),
#     (5, 0.00015384617),
#     (6, 0.00015384617),
#     (7, 0.00015384617),
#     (8, 0.00015384617),
#     (9, 0.00015384617),
#     (10, 0.00015384617),
#     (11, 0.00015384617),
#     (12, 0.00015384617),
#     (13, 0.00015384617),
#     (14, 0.00015384617),
#     (15, 0.00015384617),
#     (16, 0.00015384617),
#     (17, 0.00015384617),
#     (18, 0.00015384617),
#     (19, 0.00015384617),
#     (20, 0.00015384617),
#     (21, 0.00015384617),
#     (22, 0.00015384617),
#     (23, 0.00015384617),
#     (24, 0.00015384617),
#     (25, 0.00015384617),
#     (26, 0.00015384617),
#     (27, 0.00015384617),
#     (28, 0.00015384617),
#     (29, 0.00015384617),
#     (30, 0.00015384617),
#     (31, 0.00015384617),
#     (32, 0.00015384617),
#     (33, 0.00015384617),
#     (34, 0.00015384617),
#     (35, 0.00015384617),
#     (36, 0.00015384617),
#     (37, 0.00015384617),
#     (38, 0.00015384617),
#     (39, 0.00015384617),
#     (40, 0.00015384617),
#     (41, 0.00015384617),
#     (42, 0.00015384617),
#     (43, 0.00015384617),
#     (44, 0.00015384617),
#     (45, 0.00015384617),
#     (46, 0.00015384617),
#     (47, 0.14477983),
#     (48, 0.34111476),
#     (49, 0.00015384617)],
#    'topics2': [(0, 0.00015384615),
#     (1, 0.00015384615),
#     (2, 0.00015384615),
#     (3, 0.00015384615),
#     (4, 0.00015384615),
#     (5, 0.00015384615),
#     (6, 0.00015384615),
#     (7, 0.00015384615),
#     (8, 0.00015384615),
#     (9, 0.00015384615),
#     (10, 0.00015384615),
#     (11, 0.00015384615),
#     (12, 0.00015384615),
#     (13, 0.00015384615),
#     (14, 0.00015384615),
#     (15, 0.00015384615),
#     (16, 0.00015384615),
#     (17, 0.00015384615),
#     (18, 0.00015384615),
#     (19, 0.00015384615),
#     (20, 0.00015384615),
#     (21, 0.00015384615),
#     (22, 0.00015384615),
#     (23, 0.00015384615),
#     (24, 0.00015384615),
#     (25, 0.00015384615),
#     (26, 0.00015384615),
#     (27, 0.00015384615),
#     (28, 0.00015384615),
#     (29, 0.00015384615),
#     (30, 0.00015384615),
#     (31, 0.00015384615),
#     (32, 0.00015384615),
#     (33, 0.00015384615),
#     (34, 0.00015384615),
#     (35, 0.00015384615),
#     (36, 0.00015384615),
#     (37, 0.00015384615),
#     (38, 0.99246156),
#     (39, 0.00015384615),
#     (40, 0.00015384615),
#     (41, 0.00015384615),
#     (42, 0.00015384615),
#     (43, 0.00015384615),
#     (44, 0.00015384615),
#     (45, 0.00015384615),
#     (46, 0.00015384615),
#     (47, 0.00015384615),
#     (48, 0.00015384615),
#     (49, 0.00015384615)]})]

# %%
model_num = 0
f"topics{model_num+1}"
# Out:
# 'topics1'

# %%
for model_num in [0,1]:
    with open(f"topics_interpretation{model_num}.csv", "wt") as f:
        fieldnames = []
        csvwriter = csv.writer(f, delimiter=";")
        csvwriter.writerow(["id", "topic_terms", "text", "source", "probability", "comments"])



        for t_num in tnrange(50):
            topic_terms = models_list[model_num].print_topic(t_num, topn=20)

            csvwriter.writerow([str(t_num) + "_0_0", topic_terms, "", "", "", ""])
            for d_num, doc in enumerate(top_docs_for_topic(new_dataset, 0, t_num)):
                d_num += 1
                text = doc[1]["title"] + " " + doc[1]["content"]
                text = text.replace(";", ".").replace("\n", " ").replace("\t", " ").replace("\r", " ")
                try:
                    csvwriter.writerow(["{}_{}_0".format(t_num, d_num), "", text, doc[0], doc[1][f"topics{model_num+1}"][t_num], ""])
                except UnicodeEncodeError as err:
                    pass


                for c_num, comment in enumerate(doc[1]["comments"]):
                    c_num += 1
                    try:
                        csvwriter.writerow(["{}_{}_{}".format(t_num, d_num, c_num), "", "", "", "", "", comment[0].replace("\n", " ").replace("\t", " ").replace("\r", " ")])
                    except UnicodeEncodeError as err:
                        pass
                    
    pd.DataFrame(models_list[model_num].print_topics(num_topics=-1, num_words=20)).to_excel(f"terms_for_model_{model_num}.xlsx")
# Out:
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))

# %%
pd.DataFrame(models_list[model_num].print_topics(num_topics=-1, num_words=20)).to_excel(f"terms_fpr_model_{model_num}.xlsx")
